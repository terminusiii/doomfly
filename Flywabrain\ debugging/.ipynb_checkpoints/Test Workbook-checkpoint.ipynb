# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Test

# %% [markdown]
# ## Test2
# ![alt text](<Näyttökuva 2026-09-12 163522.png>)
# ![alt text](<Näyttökuva 2026-09-12 163801.png>)
